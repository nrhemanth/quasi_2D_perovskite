# %%
# Import the protocol files
import os
import sys
# sys.path.append(os.path.abspath('../')) 
from protocol.visualize_results import VisualizeResults

# Import necessary libraries
import pandas as pd
import numpy as np
import torch
from importlib import reload
import itertools
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import re
from scipy.stats import qmc
import random

dtype = torch.float64

# %%
# meta
# Out:
#     ID  Temperature  Anneal Time  R BAAc  R MAI   Data Tag Sample Tag  \
# 0    1         60.0         60.0   2.000  2.000  N1 R0 60C   sample 1
# 1    2         60.0         60.0   2.000  2.000  N1 R0 60C   sample 2
# 2    3         60.0         60.0   0.675  1.325  N1 R0 60C   sample 3
# 3    4         60.0         60.0   0.675  1.325  N1 R0 60C   sample 4
# 4    5         60.0         30.0   2.000  2.000  N1 R0 60C   sample 5
# 5    6         60.0         30.0   2.000  2.000  N1 R0 60C   sample 6
# 6    7         60.0         30.0   0.675  1.325  N1 R0 60C   sample 7
# 7    8         60.0         30.0   0.675  1.325  N1 R0 60C   sample 8
# 8    9         60.0          5.0   2.000  2.000  N1 R0 60C   sample 9
# 9   10         60.0          5.0   2.000  2.000  N1 R0 60C  sample 10
# 10  11         60.0          5.0   0.675  1.325  N1 R0 60C  sample 11
# 11  12         60.0          5.0   0.675  1.325  N1 R0 60C  sample 12
#
#                                               Dataset
# ...

# %%
# Photo-oxidation?
path = "experiments/N3_Campaign/Data/20250918_N3R2"
sample_case = 'sample 10_'
visualizer = VisualizeResults(path)

visualizer.plot_samples_number(sample_case)

# %%
# light-induced ion migration? n-phases are being redistributed

# Photo-oxidation?
path = "experiments/N3_Campaign/Data/20250918_N3R2"
sample_case = 'sample 1_'
visualizer = VisualizeResults(path)

visualizer.plot_samples_number(sample_case)
